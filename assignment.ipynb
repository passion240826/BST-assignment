# %% [markdown]
# # 1번
# 1. 3개 (7,17,70)
# 2. 8개 (2^(h-1)개가 최대 리프 노드수)
# 3. 1 (리프노드:8 - 내부노드:7 = 1)
# 4. yes (포화이진트리에서는 다음이 성립: 리프노드 = 내부노드 +1)

# %% [markdown]
# # 2번
# 1. ```ceil(n/2)``` 개
# 2. L을 리프노드의 수, I를 내부노드의 수 라고 하면
# - n 이 짝수일때, L = I + 1
# - n 이 홀수일때, L = I

# %% [markdown]
# #

# %% [markdown]
# # 3번
# 1.
